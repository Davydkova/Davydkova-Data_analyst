# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Анализ-оттока-клиентов-(ML)" data-toc-modified-id="Анализ-оттока-клиентов-(ML)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Анализ оттока клиентов (ML)</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-подготовка-к-анализу" data-toc-modified-id="Загрузка-данных-и-подготовка-к-анализу-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка данных и подготовка к анализу</a></span></li><li><span><a href="#EDA.-Анализ-качества-признаков" data-toc-modified-id="EDA.-Анализ-качества-признаков-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>EDA. Анализ качества признаков</a></span><ul class="toc-item"><li><span><a href="#Анализ-распределения-данных-в-признаках" data-toc-modified-id="Анализ-распределения-данных-в-признаках-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Анализ распределения данных в признаках</a></span></li><li><span><a href="#Анализ-средних-значений-в-группах" data-toc-modified-id="Анализ-средних-значений-в-группах-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Анализ средних значений в группах</a></span></li><li><span><a href="#Анализ-распределения-признаков-пользователей-отток/не-попали-в-отток" data-toc-modified-id="Анализ-распределения-признаков-пользователей-отток/не-попали-в-отток-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Анализ распределения признаков пользователей отток/не попали в отток</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Модель-прогнозирования-оттока-клиентов" data-toc-modified-id="Модель-прогнозирования-оттока-клиентов-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Модель прогнозирования оттока клиентов</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия-и-случайный-лес" data-toc-modified-id="Логистическая-регрессия-и-случайный-лес-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Логистическая регрессия и случайный лес</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Кластеризация-клиентов" data-toc-modified-id="Кластеризация-клиентов-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Кластеризация клиентов</a></span><ul class="toc-item"><li><span><a href="#Дендрограмма" data-toc-modified-id="Дендрограмма-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Дендрограмма</a></span></li><li><span><a href="#Кластеризация-на-основании-алгоритма-K-Means" data-toc-modified-id="Кластеризация-на-основании-алгоритма-K-Means-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Кластеризация на основании алгоритма K-Means</a></span></li><li><span><a href="#Визуализация-распределение-признаков-для-кластера" data-toc-modified-id="Визуализация-распределение-признаков-для-кластера-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Визуализация распределение признаков для кластера</a></span></li></ul></li><li><span><a href="#Вывод-исследования-и-базовые--рекомендации-по-работе-с-клиентами" data-toc-modified-id="Вывод-исследования-и-базовые--рекомендации-по-работе-с-клиентами-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вывод исследования и базовые  рекомендации по работе с клиентами</a></span></li></ul></div>

# %% [markdown]
# #                                Анализ оттока клиентов (ML)

# %% [markdown]
# **Описание проекта:**
#
# Фитнес центр "Культурист-датасаентист" разрабатывает стратегию взаимодействия с клиентами на основе аналитических данных.
# «Культурист-датасаентист» предоставил сведения в csv-файлах. Заказчик подготовил данные, которые содержат данные на месяц до оттока и факт оттока на определённый месяц.
#
#
# **Цель исследования:**
#
#    - спрогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента;
#    - сформировать типичные портреты клиентов: выделить несколько наиболее ярких групп и охарактеризовать их основные свойства;
#    - проанализировать основные признаки, наиболее сильно влияющие на отток;
#
# Сформулировать основные выводы и разработать рекомендации по повышению качества работы с клиентами:
#
#         1) выделить целевые группы клиентов;
#         2) предложить меры по снижению оттока;
#         3) определить другие особенности взаимодействия с клиентами.

# %% [markdown]
# ## Загрузка данных и подготовка к анализу

# %% [markdown]
# Распологаем данными на меcяц до оттока и факт оттока на определённый месяц.
#
# Спецификация по данным:
#
#    - gende — пол;
#    - Near_Location — проживание или работа в районе, где находится фитнес-центр;
#    - Partner — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента);
#    -  Promo_friends — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента);
#    - Phone — наличие контактного телефона;
#    - Age — возраст;
#    - Lifetime — время с момента первого обращения в фитнес-центр (в месяцах).
#
# Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
#
#    - Contract_period — длительность текущего действующего абонемента (месяц, 6 месяцев, год);
#    - Month_to_end_contract — срок до окончания текущего действующего абонемента (в месяцах);
#    - Group_visits — факт посещения групповых занятий;
#    - Avg_class_frequency_total — средняя частота посещений в неделю за все время с начала действия абонемента;
#    - Avg_class_frequency_current_month — средняя частота посещений в неделю за предыдущий месяц;
#    - Avg_additional_charges_total — суммарная выручка от других услуг фитнес-центра: кафе, спорттовары, косметический и массажный салон.
#
#    - Churn — факт оттока в текущем месяце.

# %%
import pandas as pd
import seaborn as sns 
from matplotlib import pyplot as plt

import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.metrics import accuracy_score, precision_score, recall_score,f1_score

from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans

import itertools


pd.options.mode.chained_assignment = None

# %%
#загрузка датасета
df=pd.read_csv('https://code.s3.yandex.net/datasets/gym_churn.csv')

# %% [markdown]
# ## EDA. Анализ качества признаков

# %%
#размер датасета
print(df.shape) 
df.sample(15)
# Out:
# (4000, 15)
#       gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 1435       0              1        1              1      1                6
# 2123       0              1        1              0      1                1
# 587        0              1        0              0      1                1
# 54         0              1        0              0      1               12
# 486        0              1        1              1      1                1
# 2753       1              1        0              0      1                1
# 3651       1              1        0              0      1               12
# 2484       0              1        1              0      1               12
# 1370       1              1        0              0      1                1
# 925        1              1        0              1      1                1
# 3236       1              1        0              0      1                1
# ...

# %%
df.columns=['gender', 'Near_Location', 'Partner', 'Promo_friends', 'Phone',
       'Contract_period', 'Group_visits', 'Age',
       'Avg_additional_charges_total', 'Month_to_end_contract', 'Lifetime',
       'Avg_class_frequency_total', 'Avg_class_frequency_current_month',
       'Churn', 'Cluster']

# %% [markdown]
# Всего 4000 наблюдений и 15 полей - 14 признаков и целевая переменная. (Churn)

# %%
#посмотрим на сводную информацию о наборе данных
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
#    - пропущенных значений в данных нет
#    - типы данных корректны
#    - все признаки численные
#    - явных дубликатов в данных не обнаружено

# %%
#статистические показатели
df.describe()
# Out:
#             gender  Near_Location      Partner  Promo_friends        Phone  \
# count  4000.000000    4000.000000  4000.000000    4000.000000  4000.000000
# mean      0.510250       0.845250     0.486750       0.308500     0.903500
# std       0.499957       0.361711     0.499887       0.461932     0.295313
# min       0.000000       0.000000     0.000000       0.000000     0.000000
# 25%       0.000000       1.000000     0.000000       0.000000     1.000000
# 50%       1.000000       1.000000     0.000000       0.000000     1.000000
# 75%       1.000000       1.000000     1.000000       1.000000     1.000000
# max       1.000000       1.000000     1.000000       1.000000     1.000000
#
#        Contract_period  Group_visits          Age  \
# count      4000.000000   4000.000000  4000.000000
# mean          4.681250      0.412250    29.184250
# std           4.549706      0.492301     3.258367
# min           1.000000      0.000000    18.000000
# ...

# %% [markdown]
# <div style="border:solid black 1px; padding: 20px">
#
#    - Средний возраст посетителей фитнес центра - 29 лет ,а максимальный возраст - 41 год.
#    - Распределение по гендерному типу равномерное
#    - 90 % посетитиелей оставляют свой номер телефона
#    - В основном посетители проживают (работают) возле фитнес центра
#    - Средний процент посетителей по акции "приведи друга" составляет 30 %
#    - Среднее время с момента первого обращения в фитнес-центр - около 4 месяцев , а максимальное - 31 месяц (похоже на аномалию)
#
#    - Большая доля посетителй оформляет абонемент на 6  месяц
#    - Около 50 %  посещают групповые занятия
#    - В среднем частота посещений фитнес центра - 2 посещения  в неделю
#
#  - Суммарная выручка от услуг фитнес-центра (кафе, спорттовары, косметический и массажный салон) - 146 условных единиц
#  - Факт оттока в текущем месяце в среднем более 25 процентов

# %% [markdown]
# ### Анализ распределения данных в признаках

# %%
#убираем вывод предупреждения
import warnings
warnings.filterwarnings('ignore')

#распределение данных в признаках 
for column in df.columns:
    plt.figure(figsize=(5, 5))
    df.groupby('Churn')[column]
    sns.distplot(df[column])
    plt.title(column)
    plt.show()

# %% [markdown]
# В основном мы имеем нормальное распределения в данных признаков

# %% [markdown]
# ### Анализ средних значений в группах

# %% [markdown]
# Посмотрим на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался

# %%
df_group=df.groupby('Churn').mean().transpose()
df_group
# Out:
# Churn                                       0           1
# gender                               0.510037    0.510839
# Near_Location                        0.873086    0.768143
# Partner                              0.534195    0.355325
# Promo_friends                        0.353522    0.183789
# Phone                                0.903709    0.902922
# Contract_period                      5.747193    1.728558
# Group_visits                         0.464103    0.268615
# Age                                 29.976523   26.989632
# Avg_additional_charges_total       158.445715  115.082899
# Month_to_end_contract                5.283089    1.662582
# Lifetime                             4.711807    0.990575
# Avg_class_frequency_total            2.024876    1.474995
# Avg_class_frequency_current_month    2.027882    1.044546

# %% [markdown]
# Вывод:

# %% [markdown]
#    - Сотрудник компании-партнёра клуба  реже склонны к оттоку
#
#    - Реже склонны к оттоку посетители приобретающее абонементы на 6 месяц
#
#    - Клиенты посещающие групповые занятия более устойчивы к оттоку
#
#    - При средней частоте посещений 2 раза неделю за предыдущий месяц - клиент скорее всего продолжит посещать наш клуб

# %% [markdown]
# ### Анализ распределения признаков пользователей отток/не попали в отток

# %% [markdown]
# Построим столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);

# %%
df_group.plot(kind='barh',figsize=(15, 12), fontsize=15, cmap='summer', grid=False)
plt.title('Распределение признаков для клиентов отток/не попали в отток', fontsize=18);

# %% [markdown]
# Данный график показывает количественное распределение признаков в зависимости от того, попал клиент в отток или нет.
#
# Интерпритация данного графика не очень интуитивная из-за разного масштаба количественных переменных.

# %%
#столбчатые гистограммы и распределения признаков 

for column in ['gender','Near_Location','Partner','Phone',
               'Contract_period','Group_visits', 'Age', 'Lifetime','Month_to_end_contract']:
    plt.figure(figsize=(10, 10))
    sns.countplot(x = df[column], hue='Churn', data=df,palette="Set3")
    plt.title(column)
    plt.show()

# %%
#столбчатые гистограммы и распределения признаков 

for column in ['Avg_additional_charges_total',
       'Avg_class_frequency_total', 'Avg_class_frequency_current_month']:
    plt.figure(figsize=(10, 10))
    sns.histplot(x = df[column], hue='Churn', data=df, palette="Set3")
    plt.title(column)
    plt.show()

# %%
# построим и отрисуем матрицу корреляций
matrix_corr=df.corr()
fig, ax = plt.subplots()

#нарисуем тепловую карту с подписями для матрицы корреляций
sns.heatmap(matrix_corr,annot=True,square=True, annot_kws = {'size':15}, cmap="YlGnBu")
#ax.set_ylim( 7, 0)  # корректировка "рваных" полей heatmap в последней версии библиотеки
sns.set(rc = {'figure.figsize':(15,15)})
plt.title('Матрица корреляций', fontsize = 25)
plt.show()

# %% [markdown]
# Итак, мы наблюдаем сильную корреляци у двух переменных. А именно:
#
#    - Avg_class_frequency_current_month (средняя частота посещений в неделю за предыдущий месяц) и Avg_class_frequency_total (средняя частота посещений в неделю за все время с начала действия абонемента). Коэффицент корреляции равен 0.95
#
#    - Contract_period — длительность текущего действующего абонемента (месяц, 6 месяцев, год) и Month_to_end_contract (срок до окончания текущего действующего абонемента (в месяцах)). Коэффицент корреляции равен 0.97
#
#
# По сути эти количественные переменные,отвечающие за признаки,  говорят между собой об одних и тех же количественных данных. Отсюда и коэффициент корреляции близится к 1. Учтем эти признаки при дальнейшем анализе данных.

# %% [markdown]
# ###  Вывод

# %% [markdown]
# <div style="border:solid black 1px; padding: 20px">
# Уровень оттока клиентов в фитнес центре снижается:
#
#     - у типа gender "0" отток меньше чем gender "1"
#
#     - большое количество партнеров
#
#     - близкое расстояние к дому/работе
#
#     - высокий лайфтайм
#
#     - частое посещение клиентом фитнес центра
#
#     - большее количество трат на доп. услуги фитнес центра
#
#     - посещение групповых занятий
#
#     - большая длительность текущего абонимента (12 месяцев)
#
#     - больший возраст клиентов

# %% [markdown]
# # Модель прогнозирования оттока клиентов

# %%
#разделим наши данные на признаки (матрица X) и целевую переменную (y)

X =df.drop('Churn', axis=1) 
y = df['Churn']

# %% [markdown]
# Мы будем использовать метод логистической регресии для бинарной классификации — это частный случай классификации,
#  когда классов всего два: "0" или "1". Целевая переменная (отток клиентов) - **бинарная величина**.
#
# Будем применять еще один метод в работе с данными - алгоритм RandomForestClassifier для задач классификации. В данном методе  деревья обучаются «параллельно» — независимо друг от друга. Обучение каждого дерева не зависит от результатов других.
#
# Диапазоны значений представленных в данных признаках сильно различаются (особенно суммарная выручка от других услуг фитнес-центр). Если мы начнём подбирать коэффициенты, заметим, что веса для разных признаков должны учитывать масштаб этих признаков. Для этого применяем стандартизацию признаков.

# %% [markdown]
# ## Логистическая регрессия и случайный лес

# %%
#разделяем модель на обучающую и валидационную выборки
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size=0.2, random_state=0)

# создадим объект класса StandardScaler и применим его к обучающей выборке
scaler = StandardScaler()

# обучаем scaler и одновременно трансформируем матрицу для обучающей выборки
X_train_st = scaler.fit_transform(X_train) 

# применяем стандартизацию к матрице признаков для тестовой выборки и валидационной
X_train_st = scaler.transform(X_train)
X_test_st = scaler.transform(X_test)

# %%
# алгоритм логистической регрессии
model = LogisticRegression(solver='liblinear', random_state=0) 

# обучим модель
model.fit(X_train_st, y_train)

# воспользуемся уже обученной моделью, чтобы сделать прогнозы
probabilities = model.predict_proba(X_test_st)[:, 1]

# бинарный прогноз
predictions = model.predict(X_test_st)

# выведим метрики для полученного прогноза
print('Метрики для модели логистической регрессии:')
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test,predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test,predictions)))
print('F1: {:.2f}'.format(f1_score(y_test,predictions)))

#алгоритм случайного дерева
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 0) 
rf_model.fit(X_train_st, y_train)
rf_predictions = rf_model.predict(X_test_st) 
rf_probabilities = rf_model.predict_proba(X_test_st)[:,1]

# выведим метрики для полученного прогноза 
print('')
print('Метрики для модели случайного леса:')
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, rf_predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, rf_predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test, rf_predictions)))
print('F1: {:.2f}'.format(f1_score(y_test,predictions)))
# Out:
# Метрики для модели логистической регрессии:
# Accuracy: 0.92
# Precision: 0.85
# Recall: 0.83
# F1: 0.84
#
# Метрики для модели случайного леса:
# Accuracy: 0.92
# Precision: 0.84
# Recall: 0.81
# F1: 0.84

# %%
print('Количественное распределение признаков клиентов при нулевом факте оттока в этом месяце',
      (df[df['Churn']==1]['Age'].count())*100/len(df), '%')
print('Количественное распределение признаков клиентов при оттоке в этом месяце',
      (df[df['Churn']==0]['Age'].count())*100/len(df), '%')
# Out:
# Количественное распределение признаков клиентов при нулевом факте оттока в этом месяце 26.525 %
# Количественное распределение признаков клиентов при оттоке в этом месяце 73.475 %

# %% [markdown]
# ## Вывод
#
# <div style="border:solid black 1px; padding: 20px">
#
# Рассчитав метрику accuracy (доля правильных ответов) мы получили положительный результат, стремящийся к 1.
# Метрики модели логистической регрессии немного лучше. Значит необходимо использовать модель логистической регрессии
# Но accuracy работает не всегда, а только при условии баланса классов — когда объектов каждого класса примерно поровну, 50% : 50%. Произведя проверку балансов класса - выявили  не равномеерное распределение около 27% (при нулевом оттоке клиентов) и 73% (при оттоке клиентов) Полагаться только на одну эту метрику нецелесообразно.
# Метрика **Precision**(точность) и **pecall**(полнота) дает лучший результат при алгоритме логистической регрессии.
# Произведен расчет еще одной сводной метрики **F1-score** (учитывающая баланс между метриками), так как precision и recall направлены на избежание противоположных рисков.
#
# **В общем и целом обе модели показали вполне отличные результаты. Метрики модели логистической регрессии немного лучше.**

# %% [markdown]
# #  Кластеризация клиентов

# %% [markdown]
# ##  Дендрограмма

# %% [markdown]
#  Построим матрицу расстояний функцией linkage() на стандартизованной матрице признаков и отобразим дендрограмму

# %%
# создаём объект класса scaler (нормализатор)
scaler = StandardScaler()
x_sc = scaler.fit_transform(df.drop(columns = ['Churn'])) # обучаем нормализатор

# %%
print(x_sc[:10])
# Out:
# [[ 0.97970588  0.42788074  1.02686062  1.49716101 -3.05985201  0.28989014
#    1.19403206 -0.0565538  -1.37753121  0.16160501 -0.19332863 -1.91191971
#   -1.67847198]
#  [-1.0207145   0.42788074 -0.973842   -0.66793083  0.32681319  1.60882159
#    1.19403206  0.55732732 -0.35021325  1.83194105  0.87368001  0.04517569
#    0.1360137 ]
#  [-1.0207145   0.42788074  1.02686062 -0.66793083  0.32681319 -0.8092194
#   -0.83749845 -0.36349436 -0.1815923  -0.79287273 -0.46008079 -0.02049263
#   -0.02901851]
#  [-1.0207145   0.42788074  1.02686062  1.49716101  0.32681319  1.60882159
#    1.19403206  1.17120844 -0.87472237  1.83194105 -0.46008079  1.36465509
#    1.51045005]
#  [ 0.97970588  0.42788074  1.02686062  1.49716101  0.32681319 -0.8092194
#   -0.83749845 -0.97737548  0.5336998  -0.79287273 -0.19332863 -0.78707638
#   -0.61454183]
#  [ 0.97970588  0.42788074 -0.973842   -0.66793083  0.32681319 -0.8092194
#    1.19403206  1.478149    3.15330097 -0.79287273 -0.19332863  0.76580519
# ...

# %%
linked = linkage(x_sc, method = 'ward')
linked
# Out:
# array([[9.70000000e+01, 3.22200000e+03, 1.00990653e-01, 2.00000000e+00],
#        [2.61000000e+02, 3.17900000e+03, 1.22634574e-01, 2.00000000e+00],
#        [8.90000000e+02, 1.75000000e+03, 1.28123291e-01, 2.00000000e+00],
#        ...,
#        [7.98700000e+03, 7.99500000e+03, 8.38725499e+01, 2.65600000e+03],
#        [7.98800000e+03, 7.99600000e+03, 8.89563592e+01, 3.03400000e+03],
#        [7.99200000e+03, 7.99700000e+03, 1.04627601e+02, 4.00000000e+03]])

# %%
plt.figure(figsize=(16, 9))  
dendrogram(linked, orientation = 'top')
plt.title('Кластеризация пользователей')
plt.show()

# %% [markdown]
# На  дендрограмме можно выделить 4,5 или 6 классов пользователей
#
# Предложенное оптимальное число кластеров 5

# %% [markdown]
# ## Кластеризация на основании алгоритма K-Means

# %%
km = KMeans(n_clusters = 5, random_state = 0)
labels = km.fit_predict(x_sc)
df['cluster'] = labels

# %%
#численность полученных класстеров
df_cluster=df.cluster.value_counts()
df_cluster
# Out:
# 3    1262
# 0    1010
# 4     838
# 2     505
# 1     385
# Name: cluster, dtype: int64

# %%
#выводим статистику по средним значениям наших признаков по кластеру
df.groupby('cluster').mean().T
# Out:
# cluster                                     0           1           2  \
# gender                               0.502970    0.522078    0.495050
# Near_Location                        0.959406    0.862338    0.000000
# Partner                              0.783168    0.470130    0.463366
# Promo_friends                        0.574257    0.306494    0.079208
# Phone                                1.000000    0.000000    1.000000
# Contract_period                     10.889109    4.787013    2.352475
# Group_visits                         0.542574    0.425974    0.215842
# Age                                 29.982178   29.301299   28.477228
# Avg_additional_charges_total       160.761016  143.957664  135.457501
# Month_to_end_contract                9.954455    4.475325    2.198020
# Lifetime                             4.736634    3.924675    2.809901
# Avg_class_frequency_total            1.982055    1.847220    1.660461
# ...

# %% [markdown]
# Самый многочисленный - **3 кластер (1262 клиента)**:
#   - отток клиентов составляет 50 %
#   - расположение фитнес центра возле дома/работы
#   - небольшая часть клиентов из данного кластера использует услугу приведи друга
#   - **абонемент приобретают в среднем на 2 месяца**
#   - **минимальное время обращения с момента первого обращения в фитнес-центр (около 2 месяцев)**
#   - **клиенты мало ходят, примерно раз в неделю**
#
# Следующий по численности - **0 кластер (1010 клиентов)**:
#   - в данном класстере **наименьший отток клиентов из всех класстеров**
#   - **клиенты приобретают в основном абонемент на 12 месяц**
#   - расположение фитнес центра возле дома/работы
#   - партнеры компании
#   - пользуются услугой приведи друга
#
#
# Кластер **4 содержит 838 клиентов**:
#  -  минимальный отток клиентов
#  -  расположение фитнес центра возле дома/работы
#  - **больше всего тратят на доп услуги фитнес центра**
#  - **максимальное время обращения с момента первого обращения в фитнес-центр (около 5 месяцев)
#  - **ходят примерно 3 раз в неделю**
#
# Кластер **2 содержит 505 клиентов**:
#   - отток клиентов составляет около 40 %
#   - фитнес центр не расположен у дома/работы
#   - в основном не пользуются услугой приведи друга
#
# **Наименьший по численности кластер 1 (385 клиента)**:
#   - отток около 30 %
#   - клиенты приобретают абонемент на 6 месяц
#   - у большинства кллиентов этого класстера фитнес центр распологается возле дома/работы
#   - **не оставляют свой номер телефона**

# %% [markdown]
# ## Визуализация распределение признаков для кластера

# %%
df.columns
# Out:
# Index(['gender', 'Near_Location', 'Partner', 'Promo_friends', 'Phone',
#        'Contract_period', 'Group_visits', 'Age',
#        'Avg_additional_charges_total', 'Month_to_end_contract', 'Lifetime',
#        'Avg_class_frequency_total', 'Avg_class_frequency_current_month',
#        'Churn', 'cluster'],
#       dtype='object')

# %%
for column in ['gender', 'Near_Location', 'Partner', 'Promo_friends', 'Phone', 
               'Contract_period', 'Group_visits', 'Age', 'Lifetime']:
    plt.figure(figsize=(15,5))
    sns.countplot(x=df[column], hue='cluster', data=df, palette="Set3")
    plt.title(column)
    plt.show()

# %%
for column in ['Avg_additional_charges_total', 'Month_to_end_contract',
       'Avg_class_frequency_total', 'Avg_class_frequency_current_month']:
    plt.figure(figsize=(15,5))
    sns.boxplot(x='cluster',y=df[column], data=df, palette="Set3")
    plt.title(column)
    plt.show()

# %%
print('Доля оттока клиентов по кластерам \n',df.groupby('cluster')['Churn'].mean())
# Out:
# Доля оттока клиентов по кластерам
#  cluster
# 0    0.027723
# 1    0.267532
# 2    0.443564
# 3    0.514263
# 4    0.068019
# Name: Churn, dtype: float64

# %% [markdown]
# # Вывод исследования и базовые  рекомендации по работе с клиентами

# %% [markdown]
# Проведя исследование мы можем сформировать портрет среднестатистического клиента фитнес центра:
#
#     - возраст около 30 лет
#     - живет/работает недалеко от фитнес-центра
#     - посещает групповые занятия
#     - абонемент в среднем на пол года
#
#
#  Исследую кластеризацию клиентов мы обнаружили 5 явных групп пользователей
#
#  Из надежных класстеров мы выделим 0 и 4 со следующими показателями.
#
#  Кластер 0 (1010 клиентов)  имеет следующие показатели:
#
#     - в данном класстере наименьший отток клиентов из всех кластеров
#     - клиенты приобретают в основном абонемент на 12 месяцев
#     - расположение фитнес центра возле дома/работы
#     - партнеры компании
#     - пользуются услугой приведи друга
#
#
#  Кластер 4 содержит 838 клиентов:
#
#     - минимальный отток клиентов
#     - расположение фитнес центра возле дома/работы
#     - больше всего тратят на доп услуги фитнес центра
#     - максимальное время обращения с момента первого обращения в фитнес-центр (около 5 месяцев)
#     - ходят примерно 3 раз в неделю
#
#
#  Сильно подвержен к оттоку 3 кластер (клиенты ходят раз в неделю, долго не задерживаются)
#
# **Рекомендации**:
#   - Глубже сегментировать клиентов уходящих в отток, к каждому сегменту тестировать индивидуальные предложения.
#   - Продолжать использовать акцию "приведи друга"
#   - Расширить программу привлечения сотрудников компаний-партнеров
#   - Расширить ассортимент доп услуг
#   - Для того чтобы уменьшить отток кластера 3, индивидуально предлагать пользователям бесплатные посещения или доп услуги со скидками.
